# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Ganti 'dataset.csv' dengan nama file datasetmu
df = pd.read_csv('8FPP21.csv')

# Cek kolom yang tersedia
df.head()
# Out:
#    Temperatur     TDS    TSS   pH   BOD   COD   DO  CurahHujan  kelas
# 0         30.1  108.2    9.5  7.8   6.9  17.2  5.1        8.45      3
# 1         26.7  108.2   18.2  7.6  14.6  39.9  5.0        8.45      4
# 2         29.6  108.2  117.7  8.0  11.2  34.3  5.2        3.43      3
# 3         29.8  108.2   66.1  7.3  12.9  32.8  5.2        3.43      4
# 4         29.0  108.2   94.3  7.8   8.6  26.0  5.3        7.39      3

# %%
# 3. Cek Missing Value
print(df.isnull().sum())
# Out:
# Temperatur     0
# TDS            0
# TSS            0
# pH             0
# BOD            0
# COD            0
# DO             0
# CurahHujan     0
# kelas          0
# dtype: int64

# %%
# Standarisasi
X = df.drop('kelas', axis=1)
y = df['kelas']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Decision Tree
dt = DecisionTreeClassifier()
kf = KFold(n_splits=10, shuffle=True, random_state=42)
dt_scores = cross_val_score(dt, X_scaled, y, cv=kf)

# SVM
svm = SVC()
svm_scores = cross_val_score(svm, X_scaled, y, cv=kf)

print("Decision Tree average accuracy:", np.mean(dt_scores))
print("SVM average accuracy:", np.mean(svm_scores))
# Out:
# Decision Tree average accuracy: 0.9484848484848485
# SVM average accuracy: 0.8538961038961039

# %%
# Decision Tree
dt_model = DecisionTreeClassifier(random_state=42)
# SVM
svm_model = SVC(kernel='rbf', random_state=42)

# 10-Fold Cross-Validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)

dt_cv_scores = cross_val_score(dt_model, X_scaled, y, cv=kf)
svm_cv_scores = cross_val_score(svm_model, X_scaled, y, cv=kf)

print(f"Decision Tree CV Accuracy: {np.mean(dt_cv_scores):.2f} ± {np.std(dt_cv_scores):.2f}")
print(f"SVM CV Accuracy: {np.mean(svm_cv_scores):.2f} ± {np.std(svm_cv_scores):.2f}")
# Out:
# Decision Tree CV Accuracy: 0.94 ± 0.06
# SVM CV Accuracy: 0.85 ± 0.08

# %%
dt_model.fit(X_scaled, y)
svm_model.fit(X_scaled, y)
# Out:
# SVC(random_state=42)

# %%
pickle.dump(dt_model, open('dt_model.pkl', 'wb'))
pickle.dump(svm_model, open('svm_model.pkl', 'wb'))
pickle.dump(scaler, open('scaler.pkl', 'wb'))

print("Model dan scaler berhasil disimpan.")
# Out:
# Model dan scaler berhasil disimpan.
